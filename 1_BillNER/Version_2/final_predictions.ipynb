# %%
import cv2
import predictions as pred

# %%
img = cv2.imread('./images/022.jpeg')
cv2.namedWindow('orginal',cv2.WINDOW_NORMAL)
cv2.imshow('orginal', img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img_results, entities = pred.get_predictions(img)
print(entities)
cv2.namedWindow('orginal',cv2.WINDOW_NORMAL)
cv2.imshow('orginal', img_results)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# Invoice no 37877758 Date of issue Seller HolmesWhitney PSC 4815, Box 7683 APO AE 56344 Tax Id 945756162 IBAN GB81XDRW19367191324873 ITEMS No. Description Qty 1 12x18 White Marble Coffee Top Table Lapis Inlay Pietradura Floral Art Decor 4,00 2. 24x24 Top Marble White Table Carnelian Marquetry Interior Thanksgiving Gift 5,00 3 24x24 Marble Black Top Coffee Table Inlaid Floral Art Christmas Gift Home Deco 3,00 4. 48 Inches Marble Coffee Table Top Inlay with Yellow Stone Art Dinette Table Top 1,00 oS 7x4 Blue Random Marble Dining Hallway Table Top Lapis Lazuli Inlay Decor E947A 3,00 SUMMARY VAT 10 Total 07/02/2014 UM each each each each each Client Jordan, Jones and Rodriguez 372 John Tunnel Patelport, SC 86533 Tax Id 953924049 Net price Net worth VAT 396,55 1 586,20 10 2 000,00 10 000,00 10 1 150,00 3 450,00 10 3 400,00 3 400,00 10 8 194,09 24 582,27 10 Net worth VAT 43 018,47 4 301,85 43 018,47 4 301,85 Gross worth 1 744,82 11 000,00 3 795,00 3 740,00 27 040,50 Gross worth 47 320,32 47 320,32
# {'ID': ['37877758'], 'DATE': ['07/02/2014'], 'SN': ['holmeswhitney'], 'CN': ['jordan jones and rodriguez'], 'IBAN': ['gb81xdrw19367191324873'], 'TOTAL': ['4732032']}
